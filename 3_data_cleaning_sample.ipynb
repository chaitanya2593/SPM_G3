# %% [markdown]
# # 3. Text data Cleaning
# -------------------
# Group 3 , September 28, 2022
# 1. Gezhi Cheng,
# 2. Haowei Lee,
# 3. Ziyi Liu,
# 4.VS Chaitanya Madduri
#
# > <i>Description: In this notebook the text data will be preprocessed</i>
#
#
# <div class="alert alert-block alert-info">
#     <b>FYI:</b> # Please run this notebook in the colab .
# </div>
#
# ### Pre requisites:
# 1. And add the shortcut of the drive link :https://drive.google.com/drive/folders/1X4UdGsQiHVWSr63FRiz8rwOuWW5Ua8uI?usp=sharing to your personal drive.
#
#
# - As the we used colab computation engine and also the files are very large in size. We used our personal google drive folders to save the large data files.
#
#
# Files:
# Selected_10k_v2.csv - to store the 10-k files of the companies selected
#
# ### Output files:
#
# Files:
# df_final.csv - To store the stemmed results and word frequencies.

# %% [markdown]
# ## 1. Import Required Packages

# %%
# Connecting to the google drive
from google.colab import drive
drive.mount('/content/drive')
from IPython.display import clear_output
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import nltk
import re 

from nltk.corpus import stopwords                         # Removing all the stopwords
from nltk.stem.porter import PorterStemmer                # Reducing words to base form

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ## 2.Loading the files to the notebook

# %% [markdown]
# ### 2.1 Load the dataframe with 10-k text

# %%
DIR_PATH = "/content/drive/MyDrive/SPM_files/"

# sample data
df = pd.read_csv(DIR_PATH + "Selected_10k_v2.csv")

# %%
df.head()
# Out:
#    Company_Key                                          Text_data  \
# 0      1069533  b'<Header>\r\n<FileStats>\r\n    <FileName>201...
# 1      1069533  b'<Header>\r\n<FileStats>\r\n    <FileName>201...
# 2      1069533  b'<Header>\r\n<FileStats>\r\n    <FileName>201...
# 3      1069533  b'<Header>\r\n<FileStats>\r\n    <FileName>201...
# 4      1069533  b'<Header>\r\n<FileStats>\r\n    <FileName>201...
#
#   Quarter_details  Year
# 0            QTR3  2013
# 1            QTR1  2014
# 2            QTR2  2014
# 3            QTR3  2014
# 4            QTR1  2015

# %% [markdown]
# ### 2.2 Extracting the 10-k fillings
#
# Some times the dataframe contains a mix of 10-K an 10-Q files and we are making sure to process only 10-K.

# %%
df['filing_type'] = np.where(df['Text_data'].str.contains("10-K_edgar_data"), "10-K", "10-Q")

# %%
df['filing_type'].value_counts()
# Out:
# 10-Q    3592
# 10-K    1184
# Name: filing_type, dtype: int64

# %%
df = df[df['filing_type'] == "10-K"]

# %%
# Reseting the index
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## 3 Stemming the Text data
#
# stemming is the process of reducing inflected (or sometimes derived) words to their word stem, base or root form—generally a written word form.

# %%
# Printing the first text record
df['Text_data'][0]
# Out:
# 'b"<Header>\\r\\n<FileStats>\\r\\n    <FileName>20111121_10-K_edgar_data_1126956_0001126956-11-000074.txt</FileName>\\r\\n    <GrossFileSize>23606915</GrossFileSize>\\r\\n    <NetFileSize>321950</NetFileSize>\\r\\n    <NonText_DocumentType_Chars>5568598</NonText_DocumentType_Chars>\\r\\n    <HTML_Chars>8845803</HTML_Chars>\\r\\n    <XBRL_Chars>6064230</XBRL_Chars>\\r\\n    <XML_Chars>2002188</XML_Chars>\\r\\n    <N_Exhibits>11</N_Exhibits>\\r\\n</FileStats>\\r\\n<SEC-Header>\\r\\n0001126956-11-000074.hdr.sgml : 20111121\\r\\n<ACCEPTANCE-DATETIME>20111118175254\\r\\nACCESSION NUMBER:\\t\\t0001126956-11-000074\\r\\nCONFORMED SUBMISSION TYPE:\\t10-K\\r\\nPUBLIC DOCUMENT COUNT:\\t\\t13\\r\\nCONFORMED PERIOD OF REPORT:\\t20110930\\r\\nFILED AS OF DATE:\\t\\t20111121\\r\\nDATE AS OF CHANGE:\\t\\t20111118\\r\\n\\r\\nFILER:\\r\\n\\r\\n\\tCOMPANY DATA:\\t\\r\\n\\t\\tCOMPANY CONFORMED NAME:\\t\\t\\tLACLEDE GROUP INC\\r\\n\\t\\tCENTRAL INDEX KEY:\\t\\t\\t0001126956\\r\\n\\t\\tSTANDARD INDUSTRIAL CLASSIFICATION:\\tNATURAL GAS DISTRIBUTION [4924]\\r\\n\\t\\tIRS NUMBER:\\t\\t\\t\\t742976504\\r\\n\\t\\tSTATE OF INCORPORATION:\\t\\t\\tMO\\r\\n\\t\\tFISCAL YEAR END:\\t\\t\\t0930\\r\\n\\r\\n\\tFILING VALUES:\\r\\n\\t\\tFORM TYPE:\\t\\t10-K\\r\\n\\t\\tSEC ACT:\\t\\t1934 Act\\r\\n\\t\\tSEC FILE NUMBER:\\t001-16681\\r\\n\\t\\tFILM NUMBER:\\t\\t111217021\\r\\n\\r\\n\\tBUSINESS ADDRESS:\\t\\r\\n\\t\\tSTREET 1:\\t\\t720 OLIVE ST\\r\\n\\t\\tCITY:\\t\\t\\tST LOUIS\\r\\n\\t\\tSTATE:\\t\\t\\tMO\\r\\n\\t\\tZIP:\\t\\t\\t63101\\r\\n\\t\\tBUSINESS PHONE:\\t\\t3143420500\\r\\n\\r\\n\\tMAIL ADDRESS:\\t\\r\\n\\t\\tSTREET 1:\\t\\t720 OLIVE ST\\r\\n\\t\\tSTREET 2:\\t\\tRM 1517\\r\\n\\t\\tCITY:\\t\\t\\tST LOUIS\\r\\n\\t\\tSTATE:\\t\\t\\tMO\\r\\n\\t\\tZIP:\\t\\t\\t63101\\r\\n\\r\\n</SEC-Header>\\r\\n</Header>\\r\\n\\r\\n 0001126956-11-000074.txt : 20111121\\r\\n\\r\\n10-K\\r\\n 1\\r\\n lacledegroupform10-k2011.htm\\r\\n THE LACLEDE GROUP, INC. FORM 10-K 2011\\r\\n\\r\\nlacledegroupform10-k2011.htm \\r\\n\\r\\nUNITED STATES \\r\\n\\r\\nSECURITIES AND EXCHANGE COMMISSION \\r\\n\\r\\nWashington, D. C. \\r\\n\\r\\nFORM 10-K \\r\\n\\r\\nANNUAL REPORT \\r\\n\\r\\nFor the Fiscal Year Ended September 30, 2011 \\r\\n\\r\\nTable of Contents \\r\\n\\r\\nUNITED STATES \\r\\n\\r\\nSECURITIES AND EXCHANGE COMMISSION \\r\\n\\r\\nWashington, D. C. 20549 \\r\\n\\r\\nFORM 10-K \\r\\n\\r\\n[ X ] \\r\\n\\r\\nANNUAL REPORT PURSUANT TO SECTION 13 or 15 (d) OF THE SECURITIES EXCHANGE ACT OF 1934 \\r\\n\\r\\nFor the Fiscal Year Ended September 30, 2011 \\r\\n\\r\\nOR \\r\\n\\r\\n[ ] \\r\\n\\r\\nTRANSITION REPORT PURSUANT TO SECTION 13 or 15 (d) OF THE SECURITIES EXCHANGE ACT OF 1934 \\r\\n\\r\\nFor the Transition Period from __________ to __________ \\r\\n\\r\\nCommission File Number 1-16681 \\r\\n\\r\\nTHE LACLEDE GROUP, INC. \\r\\n\\r\\n(Exact name of registrant as specified in its charter) \\r\\n\\r\\nMissouri \\r\\n\\r\\n(State of Incorporation) \\r\\n\\r\\n74-2976504 \\r\\n\\r\\n(I.R.S. Employer Identification number) \\r\\n\\r\\n720 Olive Street \\r\\n\\r\\nSt. Louis, MO 63101 \\r\\n\\r\\n(Address and zip code of principal executive offices) \\r\\n\\r\\n314-342-0500 \\r\\n\\r\\n(Registrant s telephone number, including area code) \\r\\n\\r\\nSecurities registered pursuant to Section 12(b) of the Act \\r\\n\\r\\nTitle of Each Class \\r\\n\\r\\nName of Each Exchange On Which Registered \\r\\n\\r\\nCommon Stock 1.00 par value \\r\\n\\r\\nNew York Stock Exchange \\r\\n\\r\\nSecurities registered pursuant to Section 12(g) of the Act: None. \\r\\n\\r\\nIndicate by check mark if the registrant: \\r\\n\\r\\nis a well-known seasoned issuer, as defined in Rule 405 of the Securities Act. Yes [ X ] No [ ] \\r\\n\\r\\nis not required to file reports pursuant to Section 13 or Section 15(d) of the Act. Yes [ ] No [ X ] \\r\\n\\r\\n(1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during the preceding 12 months (or for such shorter period t ...

# %%
df.head()
# Out:
#    Company_Key                                          Text_data  \
# 0      1126956  b"<Header>\r\n<FileStats>\r\n    <FileName>201...
# 1      1126956  b"<Header>\r\n<FileStats>\r\n    <FileName>201...
# 2      1126956  b'<Header>\r\n<FileStats>\r\n    <FileName>201...
# 3      1126956  b'<Header>\r\n<FileStats>\r\n    <FileName>201...
# 4      1126956  b'<Header>\r\n<FileStats>\r\n    <FileName>201...
#
#   Quarter_details  Year filing_type
# 0            QTR4  2011        10-K
# 1            QTR4  2011        10-K
# 2            QTR4  2012        10-K
# 3            QTR4  2012        10-K
# 4            QTR4  2013        10-K

# %%
# dividing the dataset into two chunks as for 300 records it takes around two 
#hours for processing 
# Incase we are doing a batchwise execution
# df2 = df[601:901].copy()
# df3 = df[901:].copy()

# %%
def data_clean(input_text):
    '''
    The function will do the following:
    1. Extract only the Aplhas numerical strings 
    2. Apply porter stemming which will convert a word to its root form . 
        for example : hidden will be converted to hide
    3. removes words less than 3 letters (making sure to avoid residual strings)
    Augments:
    input_text: the text to be stemmed
    
    return :
    test_process/input_text : cleaned text if there are any errors it will return the orginal text
    '''
    ps = PorterStemmer()
    try:
        test_process = re.sub('[^a-zA-Z0-9]', ' ', input_text)         # Removing special symbols like ... ! and keeping only text
        test_process = test_process.lower()                                     # Lower case
        test_process = test_process.split()                                     # string split into words
        test_process = [ps.stem(word) for word in test_process                  # reducing words to base form
              if (not word in set(stopwords.words('english')) ) and len(word)>3  ]
        test_process = " ".join(test_process)
        return test_process
    except:
        return input_text

# %% [markdown]
# ### 3.1 Removing the header tags

# %%
df['Text_data'] = df['Text_data'].str.split("</Header>").str[1]

# %% [markdown]
# Note: As below step was time taking we have disturbuted the records and ran individually in our machines and joinined the results at the end.

# %%
 # Please note this particular step takes more than an hour long time to execute.
 # For 300 records it takes around 4h.  We have processes around 900 10-k fillings
df['Text_data_cleaned'] = df['Text_data'].apply(lambda x: data_clean(x) )

# %%
df.head()
# Out:
#      Company_Key                                          Text_data  \
# 901        72741  \r\n\r\n 0000072741-17-000007.txt : 20170223\r...
# 902        72741  \r\n\r\n 0000072741-17-000007.txt : 20170223\r...
# 903        72741  \r\n\r\n 0000072741-17-000007.txt : 20170223\r...
# 904        72741  \r\n\r\n 0000072741-18-000028.txt : 20180226\r...
# 905        72741  \r\n\r\n 0000072741-18-000028.txt : 20180226\r...
#
#     Quarter_details  Year filing_type
# 901            QTR1  2017        10-K
# 902            QTR1  2017        10-K
# 903            QTR1  2017        10-K
# 904            QTR1  2018        10-K
# 905            QTR1  2018        10-K

# %%
# Saving the cleaned files to a temporary files.Namely 
# first_600.csv
# Selected_10k_cleaned_part2.csv
# Selected_10k_cleaned_part4.csv
# Selected_10k_cleaned_part3.csv


# Saving the cleaned files to a temporary file.
# df.drop(['Text_data'], axis=1).to_csv(DIR_PATH + "Selected_10k_cleaned_part3.csv")

# %%
df['Text_data_cleaned'][901]
# Out:
# '0000072741 000007 20170223 a201610kdocu ndocument nunit state secur exchang commiss washington 20549 form annual report pursuant section secur exchang 1934 nfor fiscal year end decemb 2016 ntransit report pursuant section secur exchang 1934 nfor transit period ncommiss file number registr state incorpor address telephon number employ identif 5324 eversourc energi massachusett voluntari associ cadwel drive springfield massachusett 01104 telephon 5000 2147929 00404 connecticut light power compani connecticut corpor selden street berlin connecticut 06037 1616 telephon 5000 0303850 02301 nstar electr compani massachusett corpor boylston street boston massachusett 02199 telephon 5000 1278810 6392 public servic compani hampshir hampshir corpor energi park north commerci street manchest hampshir 03101 1134 telephon 5000 0181050 7624 western massachusett electr compani massachusett corpor cadwel drive springfield massachusett 01104 telephon 5000 1961130 nsecur regist pursuant section registr titl class name exchang regist neversourc energi common share valu york stock exchang nsecur regist pursuant section registr titl class nthe connecticut light power compani prefer stock valu share issuabl seri follow seri outstand seri seri seri seri seri seri seri seri seri seri seri seri seri 1947 1947 1949 1949 1949 1954 1955 1956 1958 1963 1967 1968 1968 nstar electr compani prefer stock valu share issuabl seri follow seri outstand seri seri 1956 1958 nnstar electr compani public servic compani hampshir western massachusett electr compani meet condit forth gener instruct form therefor file form reduc disclosur format specifi gener instruct form indic check mark registr well known season issuer defin rule secur nindic check mark registr requir file report pursuant section section nindic check mark whether registr file report requir file section secur exchang 1934 preced month shorter period registr requir file report subject file requir past day nindic check mark whether registr submit electron post corpor site everi interact data file requir submit post pursuant rule regul preced month shorter period registr requir submit post file nindic check mark disclosur delinqu filer pursuant item regul contain herein contain best registr knowledg definit proxi inform statement incorpor refer part form amend form indic check mark whether registr larg acceler filer acceler filer acceler filer definit acceler filer larg acceler filer rule exchang check larg acceler filer acceler filer acceler filer neversourc energi nthe connecticut light power compani nstar electr compani public servic compani hampshir western massachusett electr compani nindic check mark whether registr shell compani defin rule exchang neversourc energi connecticut light power compani nstar electr compani public servic compani hampshir western massachusett electr compani nthe aggreg market valu eversourc energi common share valu held affili comput refer price common equiti last sold averag ask price common equiti last busi eversourc energi recent complet second fiscal quarter june 2016 base close market price share common share outstand held affili june 2016 indic number share outstand issuer class common stock latest practic date compani class stock outstand januari 2017 eversourc energi common share valu share nthe connecticut light power compani common stock valu share nnstar electr compani common stock valu share npublic servic compani hampshir common stock valu share nwestern massachusett electr compani common stock valu share neversourc energi hold share share share share outstand common stock connecticut light power compani nstar electr compani public servic compani hampshir western massachusett electr compani respect eversourc energi connecticut light power compani nstar electr compani public servic compani hampshir western massachusett electr compani separ file combin form inform contain herein relat individu registr file registr behalf registr make represent inform relat regis ...

# %% [markdown]
# ## 4. Frequency Calculations

# %%
# incase if the execution has been stopped we will continue with the saved files
df = pd.read_csv(DIR_PATH + "Selected_10k_cleaned_part2.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Company_Key Quarter_details  Year filing_type  \
# 0         601      1326160            QTR1  2019        10-K
# 1         602      1326160            QTR1  2020        10-K
# 2         603      1326160            QTR1  2020        10-K
# 3         604      1326160            QTR1  2020        10-K
# 4         605      1326160            QTR1  2020        10-K
#
#                                    Text_data_cleaned
# 0  0001326160 000057 20190228 20181231x10k form n...
# 1  0001326160 000034 20200220 20191231x10k form n...
# 2  0001326160 000034 20200220 20191231x10k form n...
# 3  0001326160 000034 20200220 20191231x10k form n...
# 4  0001326160 000034 20200220 20191231x10k form n...

# %%
# Key words for potential zombie compies (from case study)
operation_related = ["restructure", "reorganization", "reorganize", "reorganized", "reorganizing", "turnaround", "restructuring", "cost", "asset"]
credit_related = ["loan", "concession", "swap", "forgiveness", "moratorium", "bond", "covenant"]

# %%
def get_negative(data):
    '''
    The function calculates the frequency count of the negative words used on 
    the text 
    Augments:
    data: Stemmed text

    
    return :
    negative_percentage : negative words frequencey count
    '''

    DIR_PATH = "/content/drive/MyDrive/Strategy_Final/"
    negative_words = []
    with open(DIR_PATH + 'negative-words.txt', 'r') as f:
        for line in f:
            negative_words.append(line[:-1])
    # negative_words


    negative_count = 0

    words = data.split()

    for _ in words:
        if _ in negative_words:
            negative_count += 1

    negative_percentage = negative_count / len(words)

    return negative_percentage


def get_operation(data):
  '''
    The function calculates the frequency count of the operational
     words used on  the text 
    Augments:
    data: Stemmed text

    
    return :
    operation_count : operations words frequency count
    '''
    operation_count = 0

    words = data.split()

    for _ in words:
        if _ in operation_related:
            operation_count += 1
    
    return operation_count / len(words)

def get_credit(data):
  '''
    The function calculates the frequency count of the credit
     words used on  the text 
    Augments:
    data: Stemmed text

    
    return :
    operation_count : credit words frequency count
    '''
    credit_count = 0

    words = data.split()

    for _ in words:
        if _ in credit_related:
            credit_count += 1

    return credit_count / len(words)

# %%
df_final = df.copy()
#loading the saved files from the storage if the kernal breaks

# %%
df_final.head()
# Out:
#    Company_Key Quarter_details  Year filing_type  \
# 0      1126956            QTR4  2011        10-K
# 1      1126956            QTR4  2011        10-K
# 2      1126956            QTR4  2012        10-K
# 3      1126956            QTR4  2012        10-K
# 4      1126956            QTR4  2013        10-K
#
#                                    Text_data_cleaned  operation_percentage  \
# 0  0001126956 000074 20111121 lacledegroupform10 ...              0.015983
# 1  0001126956 000075 20111121 lacledegasfor10 k20...              0.019980
# 2  0001126956 000080 20121119 lacledegroupform10 ...              0.007124
# 3  0001126956 000081 20121119 lacledegasform10 k2...              0.009466
# 4  0001126956 000067 20131126 20130930x10k 2013 n...              0.010843
#
#    negative_percentage  credit_percentage       compamy_name
# 0             0.018151           0.001653  LACLEDE GROUP INC
# 1             0.017551           0.001041     LACLEDE GAS CO
# 2             0.013886           0.009069  LACLEDE GROUP INC
# 3             0.012643           0.013830     LACLEDE GAS CO
# 4             0.015798           0.008905  LACLEDE GROUP INC

# %% [markdown]
# ### 4.1 Calculation of the frequency count

# %%
# Calculating operating percentage
df_final["operation_percentage"] = df_final["Text_data_cleaned"].apply(get_operation)

# %%
# Calculating negative words percentage
df_final["negative_percentage"] = df_final["Text_data_cleaned"].apply(get_negative)

# %%
# Calculating credit words percentage
df_final["credit_percentage"] = df_final["Text_data_cleaned"].apply(get_credit)

# %%
df_final.head(2)
# Out:
#    Company_Key Quarter_details  Year filing_type  \
# 0      1126956            QTR4  2011        10-K
# 1      1126956            QTR4  2011        10-K
#
#                                    Text_data_cleaned  operation_percentage  \
# 0  0001126956 000074 20111121 lacledegroupform10 ...              0.015983
# 1  0001126956 000075 20111121 lacledegasfor10 k20...              0.019980
#
#    negative_percentage  credit_percentage
# 0             0.018151           0.001653
# 1             0.017551           0.001041

# %% [markdown]
# ### 4.2 Calculation of the frequency count

# %%
df_final.describe()
# Out:
#         Company_Key         Year  operation_percentage  negative_percentage  \
# count  1.184000e+03  1184.000000           1184.000000          1184.000000
# mean   7.263273e+05  2016.781250              0.013722             0.017724
# std    5.423365e+05     2.953907              0.003328             0.003810
# min    4.904000e+03  2011.000000              0.003845             0.005380
# 25%    7.606300e+04  2014.000000              0.011366             0.015568
# 50%    9.222240e+05  2017.000000              0.013663             0.017717
# 75%    1.109357e+06  2019.000000              0.015539             0.019801
# max    1.733998e+06  2021.000000              0.025175             0.030543
#
#        credit_percentage
# count        1184.000000
# mean            0.002527
# std             0.002245
# min             0.000184
# 25%             0.001363
# 50%             0.001856
# 75%             0.002769
# max             0.019641

# %%
df_final.head()
# Out:
#    Company_Key Quarter_details  Year filing_type  \
# 0      1126956            QTR4  2011        10-K
# 1      1126956            QTR4  2011        10-K
# 2      1126956            QTR4  2012        10-K
# 3      1126956            QTR4  2012        10-K
# 4      1126956            QTR4  2013        10-K
#
#                                    Text_data_cleaned  operation_percentage  \
# 0  0001126956 000074 20111121 lacledegroupform10 ...              0.015983
# 1  0001126956 000075 20111121 lacledegasfor10 k20...              0.019980
# 2  0001126956 000080 20121119 lacledegroupform10 ...              0.007124
# 3  0001126956 000081 20121119 lacledegasform10 k2...              0.009466
# 4  0001126956 000067 20131126 20130930x10k 2013 n...              0.010843
#
#    negative_percentage  credit_percentage       compamy_name
# 0             0.018151           0.001653  LACLEDE GROUP INC
# 1             0.017551           0.001041     LACLEDE GAS CO
# 2             0.013886           0.009069  LACLEDE GROUP INC
# 3             0.012643           0.013830     LACLEDE GAS CO
# 4             0.015798           0.008905  LACLEDE GROUP INC

# %% [markdown]
# ### 4.3 Filtering the records for company with most restructuring effects
#
# Exploratory data analysis

# %%
df_final[(df_final['operation_percentage']>0.02) & (df_final['negative_percentage']>0.025) & (df_final['operation_percentage']>0.01) ]
# Out:
#      Company_Key Quarter_details  Year filing_type  \
# 271        92521            QTR1  2014        10-K
#
#                                      Text_data_cleaned  operation_percentage  \
# 271  0000092521 000003 20140224 sps1231201310 nsp 2...              0.020494
#
#      negative_percentage  credit_percentage
# 271             0.025209           0.001278

# %%
fg = df_final[(df_final['operation_percentage']>0.0155) & (df_final['negative_percentage']>0.019) & (df_final['operation_percentage']>0.002769) ]

# %%
fg = df_final[(df_final['operation_percentage']>0.0155) & (df_final['negative_percentage']>0.019) & (df_final['operation_percentage']>0.002769) ]
# Out:
#      Company_Key Quarter_details  Year filing_type  \
# 7        1126956            QTR4  2015        10-K
# 8        1126956            QTR4  2015        10-K
# 9        1126956            QTR4  2015        10-K
# 46       1060391            QTR1  2013        10-K
# 47       1060391            QTR1  2014        10-K
# ..           ...             ...   ...         ...
# 919       827052            QTR1  2017        10-K
# 922       827052            QTR1  2019        10-K
# 923       827052            QTR1  2019        10-K
# 924       827052            QTR1  2020        10-K
# 925       827052            QTR1  2020        10-K
#
#                                      Text_data_cleaned  operation_percentage  \
# 7    0001126956 000077 20151124 lglgcagc 20150930x1...              0.015643
# 8    0001126956 000077 20151124 lglgcagc 20150930x1...              0.015643
# 9    0001126956 000077 20151124 lglgcagc 20150930x1...              0.015643
# 46   0001060391 000011 20130219 rsg2012x1231x10xk n...              0.016343
# 47   0001060391 000011 20140213 2013x1231x10xk nrsg...              0.017394
# ..                                                 ...                   ...
# 919  0000827052 000033 20170221 sce201610k ndocumen...              0.018008
# 922  0000827052 000034 20190228 sceq4201810k 2018 n...              0.017271
# 923  0000827052 000034 20190228 sceq4201810k 2018 n...              0.017271
# 924  0000827052 000026 20200227 sceq4201910k form 2...              0.017329
# 925  0000827052 000026 20200227 sceq4201910k form 2...              0.017329
#
#      negative_percentage  credit_percentage
# 7               0.019801           0.002205
# 8               0.019801           0.002205
# 9               0.019801           0.002205
# 46              0.020710           0.001245
# 47              0.020522           0.001819
# ..                   ...                ...
# 919             0.019756           0.001238
# 922             0.022162           0.000982
# 923             0.022162           0.000982
# 924             0.022413           0.001644
# 925             0.022413           0.001644
#
# [100 rows x 8 columns]

# %%
fg[(fg['Company_Key'] == 92521) & (fg['Year'] == 2019) ]['Text_data_cleaned'][922]
# Out:
# '0000827052 000034 20190228 sceq4201810k 2018 ndocument nunit state secur exchang commiss washington 20549 form mark annual report pursuant section secur exchang 1934 fiscal year end decemb 2018 transit report pursuant section secur exchang 1934 transit period commiss file number exact name registr specifi charter state jurisdict incorpor organ employ identif number 9936 edison intern california 4137452 2313 southern california edison compani california 1240335 edison intern southern california edison compani 2244 walnut grove avenu rosemead california 91770 address princip execut offic 2244 walnut grove avenu rosemead california 91770 address princip execut offic 2222 registr telephon number includ area code 1212 registr telephon number includ area code secur regist pursuant section titl class name exchang regist edison intern common stock valu nyse southern california edison compani cumul prefer stock nyse american seri seri seri seri nsecur regist pursuant section none indic check mark registr well known season issuer defin rule secur edison intern southern california edison compani indic check mark registr requir file report pursuant section section exchang edison intern southern california edison compani indic check mark whether registr file report requir file section secur exchang 1934 preced month shorter period registr requir file report subject file requir past day edison intern southern california edison compani indic check mark whether registr submit electron post corpor websit everi interact data file requir submit post pursuant rule regul chapter preced month shorter period registr requir submit post file edison intern southern california edison compani indic check mark disclosur delinqu filer pursuant item regul contain herein contain best registr knowledg definit proxi inform statement incorpor refer part form amend form edison intern southern california edison compani indic check mark whether registr larg acceler filer acceler filer acceler filer smaller report compani emerg growth compani definit larg acceler filer acceler filer smaller report compani emerg growth compani rule exchang check edison intern larg acceler filer acceler filer acceler filer smaller report compani emerg growth compani southern california edison compani larg acceler filer acceler filer acceler filer smaller report compani emerg growth compani emerg growth compani indic check mark registr elect extend transit period compli revis financi account standard provid pursuant section exchang edison intern southern california edison compani nindic check mark whether registr shell compani defin rule exchang edison intern southern california edison compani aggreg market valu vote vote common equiti held affili registr june 2018 last busi recent complet second fiscal quarter edison intern approxim billion southern california edison compani wholli own edison intern common stock outstand februari 2019 nedison intern share southern california edison compani share wholli own edison intern ndocument incorpor refer design portion proxi statement relat registr joint 2019 annual meet sharehold incorpor refer part report ntabl content nsec form refer number glossari forward look statement manag discuss analysi financi condit result oper part item manag overview nhighlight oper result n2018 gener rate case nsouthern california wildfir mudslid nperman retir onofr ntax reform nelectr industri trend ncapit program result oper nsouthern california edison compani nearn activ ncost recoveri activ nsupplement oper revenu inform nincom tax nedison intern parent nloss continu oper liquid capit resourc nsouthern california edison compani navail liquid ncapit invest plan nregulatori proceed ndecommiss onofr nsce dividend nmargin collater deposit nregulatori balanc account nedison intern parent nnet oper loss credit carryforward nhistor cash flow nsouthern california edison compani nedison intern parent ncontractu oblig conting ncontractu oblig nconting noff balanc she ...

# %%
# exporting the file for future use
# DIR_PATH = "/content/drive/MyDrive/SPM_files/"
# df_final.to_csv(DIR_PATH + "final_df.csv", index=None)

# %% [markdown]
# ## End of the Notebook
